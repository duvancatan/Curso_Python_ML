# %% [markdown]
# # PANDAS SQL

# %%
import numpy as np
import pandas as pd
import os

# %%
mainpath= "C:/Users/ducatano/Desktop/Curso de Python Bancolombia" #Cuando aparece "\" coloco r adelante
filename= "Telco.csv"
fullpath= os.path.join(mainpath,filename)
#Cargar los datos. 
data= pd.read_csv(fullpath, sep=",")
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ...  DeviceProtection  \
# 0  No phone service             DSL             No  ...                No
# 1                No             DSL            Yes  ...               Yes
# 2                No             DSL            Yes  ...                No
# 3  No phone service             DSL            Yes  ...               Yes
# 4                No     Fiber optic             No  ...                No
#
# ...

# %%
data[["gender", "Partner", "Dependents", "TotalCharges"]].head(5)
# Out:
#    gender Partner Dependents TotalCharges
# 0  Female     Yes         No        29.85
# 1    Male      No         No       1889.5
# 2    Male      No         No       108.15
# 3    Male      No         No      1840.75
# 4  Female      No         No       151.65

# %%
data[data["gender"]=="Female"].head() #WHERE
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
# 5  9305-CDSKC  Female              0      No         No       8          Yes
# 7  6713-OKOMC  Female              0      No         No      10           No
# 8  7892-POOKP  Female              0     Yes         No      28          Yes
#
#       MultipleLines InternetService OnlineSecurity  ...  DeviceProtection  \
# 0  No phone service             DSL             No  ...                No
# 4                No     Fiber optic             No  ...                No
# 5               Yes     Fiber optic             No  ...               Yes
# 7  No phone service             DSL            Yes  ...                No
# 8               Yes     Fiber optic             No  ...               Yes
#
# ...

# %%
is_female=data["gender"]=="Female"
is_female.value_counts() #CONTEO
# Out:
# False    3555
# True     3488
# Name: gender, dtype: int64

# %%
data[ (data["gender"]=="Female") & (data["tenure"]>10.00) ].head() #AND
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 8   7892-POOKP  Female              0     Yes         No      28          Yes
# 15  3655-SNQYZ  Female              0     Yes        Yes      69          Yes
# 16  8191-XWSZG  Female              0      No         No      52          Yes
# 19  4183-MYFRB  Female              0      No         No      21          Yes
# 23  3638-WEABW  Female              0     Yes         No      58          Yes
#
#    MultipleLines InternetService       OnlineSecurity  ...   \
# 8            Yes     Fiber optic                   No  ...
# 15           Yes     Fiber optic                  Yes  ...
# 16            No              No  No internet service  ...
# 19            No     Fiber optic                   No  ...
# 23           Yes             DSL                   No  ...
#
#        DeviceProtection          TechSupport          StreamingTV  \
# 8                   Yes                  Yes                  Yes
# ...

# %%
data[ (data["gender"]=="Female") | (data["tenure"]>10.00) ].head() #OR
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
# 5  9305-CDSKC  Female              0      No         No       8          Yes
#
#       MultipleLines InternetService OnlineSecurity  ...  DeviceProtection  \
# 0  No phone service             DSL             No  ...                No
# 1                No             DSL            Yes  ...               Yes
# 3  No phone service             DSL            Yes  ...               Yes
# 4                No     Fiber optic             No  ...                No
# 5               Yes     Fiber optic             No  ...               Yes
#
# ...
