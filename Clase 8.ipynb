# %%
from pandasql import sqldf
import pandas as pd
from sklearn.datasets import load_iris
from pandasql import sqldf
from pandasql import load_meat, load_births
import re
import numpy as np
import os

# %%
mainpath= "C:/Users/ducatano/Desktop/Curso de Python Bancolombia" #Cuando aparece "\" coloco r adelante
filename= "Bank.csv"
fullpath= os.path.join(mainpath,filename)
#Cargar los datos. 
data= pd.read_csv(fullpath, sep=",")
data.head()
# Out:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
# 3   55    services  married  secondary      no     2476     yes   no  unknown
# 4   54      admin.  married   tertiary      no      184      no   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes
# 3    5   may       579         1     -1         0  unknown     yes
# 4    5   may       673         2     -1         0  unknown     yes

# %%
data.shape
# Out:
# (11162, 17)

# %%
data.describe
# Out:
# <bound method NDFrame.describe of        age            job   marital  education default  balance housing loan  \
# 0       59         admin.   married  secondary      no     2343     yes   no
# 1       56         admin.   married  secondary      no       45      no   no
# 2       41     technician   married  secondary      no     1270     yes   no
# 3       55       services   married  secondary      no     2476     yes   no
# 4       54         admin.   married   tertiary      no      184      no   no
# 5       42     management    single   tertiary      no        0     yes  yes
# 6       56     management   married   tertiary      no      830     yes  yes
# 7       60        retired  divorced  secondary      no      545     yes   no
# 8       37     technician   married  secondary      no        1     yes   no
# 9       28       services    single  secondary      no     5090     yes   no
# 10      38         admin.    single  secondary      no      100     yes   no
# ...

# %%
data.dtypes
# Out:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# deposit      object
# dtype: object

# %%
data[["marital", "housing", "deposit"]].describe()
# Out:
#         marital housing deposit
# count     11162   11162   11162
# unique        3       2       2
# top     married      no      no
# freq       6351    5881    5873

# %%
data.describe()
# Out:
#                 age       balance           day      duration      campaign  \
# count  11162.000000  11162.000000  11162.000000  11162.000000  11162.000000
# mean      41.231948   1528.538524     15.658036    371.993818      2.508421
# std       11.913369   3225.413326      8.420740    347.128386      2.722077
# min       18.000000  -6847.000000      1.000000      2.000000      1.000000
# 25%       32.000000    122.000000      8.000000    138.000000      1.000000
# 50%       39.000000    550.000000     15.000000    255.000000      2.000000
# 75%       49.000000   1708.000000     22.000000    496.000000      3.000000
# max       95.000000  81204.000000     31.000000   3881.000000     63.000000
#
#               pdays      previous
# count  11162.000000  11162.000000
# mean      51.330407      0.832557
# std      108.758282      2.292007
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# 75%       20.750000      1.000000
# ...

# %%
data["marital"].unique()
# Out:
# array(['married', 'single', 'divorced'], dtype=object)

# %%
data[data["marital"]=="single"].describe()
# Out:
#                age       balance          day     duration     campaign  \
# count  3518.000000   3518.000000  3518.000000  3518.000000  3518.000000
# mean     33.017339   1457.255259    15.608869   384.195566     2.323195
# std       7.685012   2940.061288     8.612100   346.695024     2.341327
# min      18.000000  -1139.000000     1.000000     4.000000     1.000000
# 25%      28.000000    145.000000     8.000000   152.000000     1.000000
# 50%      31.000000    539.500000    15.000000   268.000000     2.000000
# 75%      36.000000   1583.750000    22.000000   513.000000     3.000000
# max      86.000000  56831.000000    31.000000  3253.000000    30.000000
#
#              pdays     previous
# count  3518.000000  3518.000000
# mean     56.344798     0.913019
# std     112.916775     2.431980
# min      -1.000000     0.000000
# 25%      -1.000000     0.000000
# 50%      -1.000000     0.000000
# 75%      88.000000     1.000000
# max     804.000000    40.000000

# %%
casada = data[data["marital"]=="married"]
casada["job"].describe()
# Out:
# count           6351
# unique            12
# top       management
# freq            1428
# Name: job, dtype: object

# %%
solterona = data[(data["marital"]=="single") & (data["age"]>=30)]
solterona
# Out:
#        age            job marital  education default  balance housing loan  \
# 5       42     management  single   tertiary      no        0     yes  yes
# 10      38         admin.  single  secondary      no      100     yes   no
# 13      46    blue-collar  single   tertiary      no      460     yes   no
# 14      31     technician  single   tertiary      no      703     yes   no
# 16      32    blue-collar  single    primary      no      611     yes   no
# 21      43     management  single   tertiary      no     2067     yes   no
# 24      37     unemployed  single  secondary      no      381     yes   no
# 25      35    blue-collar  single  secondary      no       40     yes   no
# 26      31     technician  single   tertiary      no       22     yes   no
# 27      43    blue-collar  single  secondary      no        3     yes   no
# 35      32     management  single   tertiary      no      311      no   no
# ...

# %%
#Salvavidas
data.columns = [re.sub("[() ]", "", col) for col in data.columns]

# %%
data2 = sqldf("SELECT age, job, marital  FROM data LIMIT 10;")
print(data2)
# Out:
#    age         job   marital
# 0   59      admin.   married
# 1   56      admin.   married
# 2   41  technician   married
# 3   55    services   married
# 4   54      admin.   married
# 5   42  management    single
# 6   56  management   married
# 7   60     retired  divorced
# 8   37  technician   married
# 9   28    services    single
